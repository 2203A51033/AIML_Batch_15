# %% [markdown]
# <a href="https://colab.research.google.com/github/2203A51033/AIML_Batch_15/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,fontstyle='italic')
# Out:
# Text(0.5, 1.0, "People's weight in kgs")

# %%
people = ["Anna", "Pip", "Adeline", "Zade", "Dia"]
height = [170, 180, 160, 175, 185]
weight = [70, 80, 75, 85, 90]

# %%
# Main plot function 'bar'
plt.bar(people, height=weight, width=0.6, color='blue', edgecolor='k', alpha=0.6)
plt.xlabel("People", fontsize=15)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)", fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))

# %%
#Main plot function'hist'
plt.hist(weight, color='red', edgecolor='k', alpha=0.75, bins=5)
# Out:
# (array([1., 1., 1., 1., 1.]),
#  array([70., 74., 78., 82., 86., 90.]),
#  <BarContainer object of 5 artists>)

# %%
plt.title("Histogram of Patient Weights", fontsize=18)
plt.xlabel("Weight in kgs", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
